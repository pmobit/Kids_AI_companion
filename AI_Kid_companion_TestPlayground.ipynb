# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
import random

nltk.download('vader_lexicon')

class KidCompanion:
    def __init__(self):
        self.sia = SentimentIntensityAnalyzer()

    def analyze_stress_level(self, text):
        # Use sentiment analysis to determine stress level
        sentiment_score = self.sia.polarity_scores(text)['compound']

        if sentiment_score < -0.5:
            return "high"
        elif sentiment_score < 0:
            return "medium"
        else:
            return "low"

    def calm_kid(self, stress_level):
        # Calm the kid based on stress level
        if stress_level == "high":
            return "I'm here for you! Let's take a deep breath together. What's on your mind?"
        elif stress_level == "medium":
            return "It's okay, I understand you might be feeling a bit uneasy. How about we talk about something you enjoy?"
        else:
            return "Great to hear that you're feeling okay! Anything specific you'd like to chat about or do?"

if __name__ == "__main__":
    # Example usage
    kid_companion = KidCompanion()

    # Simulate a conversation with the kid
    kid_input = input("Kid: ")
    stress_level = kid_companion.analyze_stress_level(kid_input)
    calming_message = kid_companion.calm_kid(stress_level)

    print("AI Companion:", calming_message)
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/pooyan/nltk_data...
# Kid: i am not ok
# AI Companion: It's okay, I understand you might be feeling a bit uneasy. How about we talk about something you enjoy?

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

nltk.download('vader_lexicon')

class KidCompanion:
    def __init__(self):
        self.sia = SentimentIntensityAnalyzer()

    def analyze_stress_level(self, text):
        sentiment_score = self.sia.polarity_scores(text)['compound']

        if sentiment_score < -0.5:
            return "high"
        elif sentiment_score < 0:
            return "medium"
        else:
            return "low"

    def calm_kid(self, stress_level):
        if stress_level == "high":
            return "I'm here for you! Let's take a deep breath together. What's on your mind?"
        elif stress_level == "medium":
            return "It's okay, I understand you might be feeling a bit uneasy. How about we talk about something you enjoy?"
        else:
            return "Great to hear that you're feeling okay! Anything specific you'd like to chat about or do?"

if __name__ == "__main__":
    kid_companion = KidCompanion()

    while True:
        kid_input = input("Kid: ")
        
        if kid_input.lower() in ["exit", "bye", "quit"]:
            print("Goodbye! Take care.")
            break

        stress_level = kid_companion.analyze_stress_level(kid_input)
        calming_message = kid_companion.calm_kid(stress_level)

        print("AI Companion:", calming_message)
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/pooyan/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Kid: i am not ok
# AI Companion: It's okay, I understand you might be feeling a bit uneasy. How about we talk about something you enjoy?
# Kid: how can i feel better?
# AI Companion: Great to hear that you're feeling okay! Anything specific you'd like to chat about or do?
# Kid: i am not so good
# AI Companion: It's okay, I understand you might be feeling a bit uneasy. How about we talk about something you enjoy?
# Kid: how can i do that?
# AI Companion: Great to hear that you're feeling okay! Anything specific you'd like to chat about or do?
# Kid: exit
# Goodbye! Take care.

# %%
import spacy
import random

class KidCompanion:
    def __init__(self):
        self.nlp = spacy.load("en_core_web_sm")

    def analyze_stress_level(self, text):
        # Use spaCy for more advanced context-aware analysis
        doc = self.nlp(text)
        sentiment_score = doc.sentiment

        if sentiment_score < -0.1:
            return "high"
        elif sentiment_score < 0.1:
            return "medium"
        else:
            return "low"

    def calm_kid(self, stress_level, context):
        # Enhanced responses based on context
        high_stress_responses = [
            "I understand it can be challenging, especially in the hospital. How about we focus on something positive to lighten the mood?",
            "Dealing with hospital stays is tough. Let's talk through it together. What would make you feel a bit better right now?",
            "Your strength in facing challenges is admirable. Share your thoughts, and we'll navigate through them together."
        ]

        medium_stress_responses = [
            "It's normal to feel a bit uneasy, especially in a hospital. What specific things can we discuss to make you more comfortable?",
            "Hospitals can be overwhelming, but we can find ways to make it more manageable. What activities or topics interest you?",
            "Let's create a positive distraction together. What would you enjoy chatting about right now?"
        ]

        low_stress_responses = [
            "I'm delighted to hear that you're doing well! Anything specific you'd like to talk about or explore during your time in the hospital?",
            "Your positivity is contagious! What can we do together to make your hospital experience more enjoyable?",
            "You're handling things remarkably well! Is there anything on your mind that you'd like to share or discuss?"
        ]

        if stress_level == "high":
            return random.choice(high_stress_responses)
        elif stress_level == "medium":
            return random.choice(medium_stress_responses)
        else:
            return random.choice(low_stress_responses)

if __name__ == "__main__":
    kid_companion = KidCompanion()

    print("AI Companion: Hi there! I'm here to chat and provide support during your time in the hospital. If you need anything specific, feel free to let me know. If you want to end our conversation, just type 'exit'.")

    while True:
        kid_input = input("Kid: ").lower()
        
        if kid_input in ["exit", "bye", "quit"]:
            print("AI Companion: Goodbye! Wishing you a speedy recovery.")
            break

        stress_level = kid_companion.analyze_stress_level(kid_input)
        calming_message = kid_companion.calm_kid(stress_level, kid_input)

        print("AI Companion:", calming_message)
# Out:
# AI Companion: Hi there! I'm here to chat and provide support during your time in the hospital. If you need anything specific, feel free to let me know. If you want to end our conversation, just type 'exit'.
# Kid: i am not feeling ok
# AI Companion: Hospitals can be overwhelming, but we can find ways to make it more manageable. What activities or topics interest you?
# Kid: tennis
# AI Companion: Hospitals can be overwhelming, but we can find ways to make it more manageable. What activities or topics interest you?
# Kid: exit
# AI Companion: Goodbye! Wishing you a speedy recovery.

# %%
pip install spacy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 22.8 MB/s eta 0:00:0000:0100:01
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
import random

class KidCompanion:
    def __init__(self):
        self.nlp = spacy.load("en_core_web_sm")

    def analyze_stress_level(self, text):
        doc = self.nlp(text)
        sentiment_score = doc.sentiment

        if sentiment_score < -0.1:
            return "high"
        elif sentiment_score < 0.1:
            return "medium"
        else:
            return "low"

    def calm_kid(self, stress_level, context):
        high_stress_responses = [
            "I understand it can be challenging, especially in the hospital. How about we focus on something positive to lighten the mood?",
            "Dealing with hospital stays is tough. Let's talk through it together. What would make you feel a bit better right now?",
            "Your strength in facing challenges is admirable. Share your thoughts, and we'll navigate through them together."
        ]

        medium_stress_responses = [
            "It's normal to feel a bit uneasy, especially in a hospital. What specific things can we discuss to make you more comfortable?",
            "Hospitals can be overwhelming, but we can find ways to make it more manageable. What activities or topics interest you?",
            "Let's create a positive distraction together. What would you enjoy chatting about right now?"
        ]

        low_stress_responses = [
            "I'm glad you're feeling okay! Hospitals aren't the most fun places. Is there anything you'd like to chat about or do to pass the time?",
            "Great to hear that you're doing well! Anything specific on your mind? We can talk about anything you like.",
            "Being in the hospital might not be ideal, but your positive attitude is inspiring. What can we do to make your day a bit brighter?"
        ]

        if stress_level == "high":
            return random.choice(high_stress_responses)
        elif stress_level == "medium":
            return random.choice(medium_stress_responses)
        else:
            return random.choice(low_stress_responses)

    def respond_to_kid_answer(self, kid_answer):
        return f"AI Companion: That's awesome! {kid_answer.capitalize()} sounds like a great choice. Tell me more about it or anything else you'd like to discuss."

if __name__ == "__main__":
    kid_companion = KidCompanion()

    print("AI Companion: Hi there! I'm here to chat and provide support during your time in the hospital. If you need anything specific, feel free to let me know. If you want to end our conversation, just type 'exit'.")

    while True:
        kid_input = input("Kid: ").lower()
        
        if kid_input in ["exit", "bye", "quit"]:
            print("AI Companion: Goodbye! Wishing you a speedy recovery.")
            break

        stress_level = kid_companion.analyze_stress_level(kid_input)
        calming_message = kid_companion.calm_kid(stress_level, kid_input)
        print("AI Companion:", calming_message)

        kid_answer = input("Kid: ")
        reply = kid_companion.respond_to_kid_answer(kid_answer)
        print(reply)
# Out:
# AI Companion: Hi there! I'm here to chat and provide support during your time in the hospital. If you need anything specific, feel free to let me know. If you want to end our conversation, just type 'exit'.
# Kid: i am not ok today
# AI Companion: Let's create a positive distraction together. What would you enjoy chatting about right now?
# Kid: sport
# AI Companion: That's awesome! Sport sounds like a great choice. Tell me more about it or anything else you'd like to discuss.
# Kid: my favorite sport is football
# AI Companion: It's normal to feel a bit uneasy, especially in a hospital. What specific things can we discuss to make you more comfortable?
# Kid: exit
# AI Companion: That's awesome! Exit sounds like a great choice. Tell me more about it or anything else you'd like to discuss.
# Kid: exit
# AI Companion: Goodbye! Wishing you a speedy recovery.

# %%
import spacy
import random

class KidCompanion:
    def __init__(self):
        self.nlp = spacy.load("en_core_web_sm")

    def analyze_stress_level(self, text):
        doc = self.nlp(text)
        sentiment_score = doc.sentiment

        if sentiment_score < -0.1:
            return "high"
        elif sentiment_score < 0.1:
            return "medium"
        else:
            return "low"

    def calm_kid(self, stress_level, context):
        high_stress_responses = [
            "I understand it can be challenging, especially in the hospital. How about we focus on something positive to lighten the mood?",
            "Dealing with hospital stays is tough. Let's talk through it together. What would make you feel a bit better right now?",
            "Your strength in facing challenges is admirable. Share your thoughts, and we'll navigate through them together."
        ]

        medium_stress_responses = [
            "It's normal to feel a bit uneasy, especially in a hospital. What specific things can we discuss to make you more comfortable?",
            "Hospitals can be overwhelming, but we can find ways to make it more manageable. What activities or topics interest you?",
            "Let's create a positive distraction together. What would you enjoy chatting about right now?"
        ]

        low_stress_responses = [
            "I'm glad you're feeling okay! Hospitals aren't the most fun places. Is there anything you'd like to chat about or do to pass the time?",
            "Great to hear that you're doing well! Anything specific on your mind? We can talk about anything you like.",
            "Being in the hospital might not be ideal, but your positive attitude is inspiring. What can we do to make your day a bit brighter?"
        ]

        if stress_level == "high":
            return random.choice(high_stress_responses)
        elif stress_level == "medium":
            return random.choice(medium_stress_responses)
        else:
            return random.choice(low_stress_responses)

    def respond_to_kid_answer(self, kid_answer, stress_level):
        if "exit" in kid_answer.lower():
            return "AI Companion: It's okay. If you ever need to talk or if there's anything specific on your mind, feel free to reach out. Take care and wishing you a speedy recovery!"

        if stress_level == "high":
            return "AI Companion: I appreciate you sharing your thoughts. Let's continue the conversation. Is there something in particular that's bothering you, or is there a topic you'd like to discuss to distract yourself?"

        elif stress_level == "medium":
            return f"AI Companion: That's great to hear! {kid_answer.capitalize()} sounds interesting. How does it usually make you feel? Is there anything related to it that you'd like to explore or discuss further?"

        else:
            return f"AI Companion: Fantastic choice! {kid_answer.capitalize()} is a positive topic. What other things bring you joy or make your time in the hospital more enjoyable?"

if __name__ == "__main__":
    kid_companion = KidCompanion()

    print("AI Companion: Hi there! I'm here to chat and provide support during your time in the hospital. If you need anything specific, feel free to let me know. If you want to end our conversation, just type 'exit'.")

    while True:
        kid_input = input("Kid: ").lower()
        
        if "exit" in kid_input:
            print("AI Companion: Goodbye! Wishing you a speedy recovery.")
            break

        stress_level = kid_companion.analyze_stress_level(kid_input)
        calming_message = kid_companion.calm_kid(stress_level, kid_input)
        print("AI Companion:", calming_message)

        kid_answer = input("Kid: ")
        reply = kid_companion.respond_to_kid_answer(kid_answer, stress_level)
        print(reply)
# Out:
# AI Companion: Hi there! I'm here to chat and provide support during your time in the hospital. If you need anything specific, feel free to let me know. If you want to end our conversation, just type 'exit'.
# Kid: I am not feeling ok!
# AI Companion: Hospitals can be overwhelming, but we can find ways to make it more manageable. What activities or topics interest you?
# Kid: sport
# AI Companion: That's great to hear! Sport sounds interesting. How does it usually make you feel? Is there anything related to it that you'd like to explore or discuss further?
# Kid: my favorite sport
# AI Companion: It's normal to feel a bit uneasy, especially in a hospital. What specific things can we discuss to make you more comfortable?
# Kid: exit
# AI Companion: It's okay. If you ever need to talk or if there's anything specific on your mind, feel free to reach out. Take care and wishing you a speedy recovery!
# Kid: exit
# AI Companion: Goodbye! Wishing you a speedy recovery.

# %%
import spacy
import random

class KidCompanion:
    def __init__(self):
        self.nlp = spacy.load("en_core_web_sm")

    def analyze_stress_level(self, text):
        doc = self.nlp(text)
        sentiment_score = doc.sentiment

        if sentiment_score < -0.1:
            return "high"
        elif sentiment_score < 0.1:
            return "medium"
        else:
            return "low"

    def calm_kid(self, stress_level, context):
        high_stress_responses = [
            "I understand it can be challenging, especially in the hospital. How about we focus on something positive to lighten the mood?",
            "Dealing with hospital stays is tough. Let's talk through it together. What would make you feel a bit better right now?",
            "Your strength in facing challenges is admirable. Share your thoughts, and we'll navigate through them together."
        ]

        medium_stress_responses = [
            "It's normal to feel a bit uneasy, especially in a hospital. What specific things can we discuss to make you more comfortable?",
            "Hospitals can be overwhelming, but we can find ways to make it more manageable. What activities or topics interest you?",
            "Let's create a positive distraction together. What would you enjoy chatting about right now?"
        ]

        low_stress_responses = [
            "I'm glad you're feeling okay! Hospitals aren't the most fun places. Is there anything you'd like to chat about or do to pass the time?",
            "Great to hear that you're doing well! Anything specific on your mind? We can talk about anything you like.",
            "Being in the hospital might not be ideal, but your positive attitude is inspiring. What can we do to make your day a bit brighter?"
        ]

        if stress_level == "high":
            return random.choice(high_stress_responses)
        elif stress_level == "medium":
            return random.choice(medium_stress_responses)
        else:
            return random.choice(low_stress_responses)

    def respond_to_kid_answer(self, kid_answer, stress_level):
        if "exit" in kid_answer.lower():
            return "AI Companion: It's okay. If you ever need to talk or if there's anything specific on your mind, feel free to reach out. Take care and wishing you a speedy recovery!"

        if stress_level == "high":
            responses = [
                "AI Companion: I appreciate you sharing your thoughts. Let's continue the conversation. Is there something in particular that's bothering you, or is there a topic you'd like to discuss to distract yourself?",
                "AI Companion: Thank you for opening up. How about we explore some positive aspects of your day or discuss things that bring you comfort?"
            ]
            return random.choice(responses)

        elif stress_level == "medium":
            return f"AI Companion: That's great to hear! {kid_answer.capitalize()} sounds interesting. How does it usually make you feel? Is there anything related to it that you'd like to explore or discuss further?"

        else:
            return f"AI Companion: Fantastic choice! {kid_answer.capitalize()} is a positive topic. What other things bring you joy or make your time in the hospital more enjoyable?"

if __name__ == "__main__":
    kid_companion = KidCompanion()

    print("AI Companion: Hi there! I'm here to chat and provide support during your time in the hospital. If you need anything specific, feel free to let me know. If you want to end our conversation, just type 'exit'.")

    while True:
        kid_input = input("Kid: ").lower()
        
        if "exit" in kid_input:
            print("AI Companion: Goodbye! Wishing you a speedy recovery.")
            break

        stress_level = kid_companion.analyze_stress_level(kid_input)
        calming_message = kid_companion.calm_kid(stress_level, kid_input)
        print("AI Companion:", calming_message)

        kid_answer = input("Kid: ")
        reply = kid_companion.respond_to_kid_answer(kid_answer, stress_level)
        print(reply)
# Out:
# AI Companion: Hi there! I'm here to chat and provide support during your time in the hospital. If you need anything specific, feel free to let me know. If you want to end our conversation, just type 'exit'.
# Kid: i am not feeling good today at hospital
# AI Companion: Hospitals can be overwhelming, but we can find ways to make it more manageable. What activities or topics interest you?
# Kid: sport is my favorite topic
# AI Companion: That's great to hear! Sport is my favorite topic sounds interesting. How does it usually make you feel? Is there anything related to it that you'd like to explore or discuss further?
# Kid:  i am ok
# AI Companion: Let's create a positive distraction together. What would you enjoy chatting about right now?
# Kid: i am ok now thanks
# AI Companion: That's great to hear! I am ok now thanks sounds interesting. How does it usually make you feel? Is there anything related to it that you'd like to explore or discuss further?
# Kid: bye
# ...

# %%
import spacy
import random

class KidCompanion:
    def __init__(self):
        self.nlp = spacy.load("en_core_web_sm")

    def analyze_stress_level(self, text):
        doc = self.nlp(text)
        sentiment_score = doc.sentiment

        if sentiment_score < -0.1:
            return "high"
        elif sentiment_score < 0.1:
            return "medium"
        else:
            return "low"

    def calm_kid(self, stress_level, context):
        high_stress_responses = [
            "I understand it can be challenging, especially in the hospital. How about we focus on something positive to lighten the mood?",
            "Dealing with hospital stays is tough. Let's talk through it together. What would make you feel a bit better right now?",
            "Your strength in facing challenges is admirable. Share your thoughts, and we'll navigate through them together."
        ]

        medium_stress_responses = [
            "It's normal to feel a bit uneasy, especially in a hospital. What specific things can we discuss to make you more comfortable?",
            "Hospitals can be overwhelming, but we can find ways to make it more manageable. What activities or topics interest you?",
            "Let's create a positive distraction together. What would you enjoy chatting about right now?"
        ]

        low_stress_responses = [
            "I'm glad you're feeling okay! Hospitals aren't the most fun places. Is there anything you'd like to chat about or do to pass the time?",
            "Great to hear that you're doing well! Anything specific on your mind? We can talk about anything you like.",
            "Being in the hospital might not be ideal, but your positive attitude is inspiring. What can we do to make your day a bit brighter?"
        ]

        if stress_level == "high":
            return random.choice(high_stress_responses)
        elif stress_level == "medium":
            return random.choice(medium_stress_responses)
        else:
            return random.choice(low_stress_responses)

    def respond_to_kid_answer(self, kid_answer, stress_level):
        if "exit" in kid_answer.lower():
            return "AI Companion: It's okay. If you ever need to talk or if there's anything specific on your mind, feel free to reach out. Take care and wishing you a speedy recovery!"

        if stress_level == "high":
            responses = [
                "AI Companion: I appreciate you sharing your thoughts. Let's continue the conversation. Is there something in particular that's bothering you, or is there a topic you'd like to discuss to distract yourself?",
                "AI Companion: Thank you for opening up. How about we explore some positive aspects of your day or discuss things that bring you comfort?"
            ]
            return random.choice(responses)

        elif stress_level == "medium":
            return f"AI Companion: That's great to hear! {kid_answer.capitalize()} sounds interesting. How does it usually make you feel? Is there anything related to it that you'd like to explore or discuss further?"

        else:
            return f"AI Companion: Fantastic choice! {kid_answer.capitalize()} is a positive topic. What other things bring you joy or make your time in the hospital more enjoyable?"

if __name__ == "__main__":
    kid_companion = KidCompanion()

    print("AI Companion: Hi there! I'm here to chat and provide support during your time in the hospital. If you need anything specific, feel free to let me know. If you want to end our conversation, just type 'exit'.")

    while True:
        kid_input = input("Kid: ").lower()
        
        if "exit" in kid_input:
            print("AI Companion: Goodbye! Wishing you a speedy recovery.")
            break

        stress_level = kid_companion.analyze_stress_level(kid_input)
        calming_message = kid_companion.calm_kid(stress_level, kid_input)
        print("AI Companion:", calming_message)

        kid_answer = input("Kid: ")
        reply = kid_companion.respond_to_kid_answer(kid_answer, stress_level)
        print(reply)
# Out:
# AI Companion: Hi there! I'm here to chat and provide support during your time in the hospital. If you need anything specific, feel free to let me know. If you want to end our conversation, just type 'exit'.
# Kid: i am not ok
# AI Companion: Let's create a positive distraction together. What would you enjoy chatting about right now?
# Kid: lets talk about sport
# AI Companion: That's great to hear! Lets talk about sport sounds interesting. How does it usually make you feel? Is there anything related to it that you'd like to explore or discuss further?
# Kid: bye
# AI Companion: Hospitals can be overwhelming, but we can find ways to make it more manageable. What activities or topics interest you?
# Kid: bye
# AI Companion: That's great to hear! Bye sounds interesting. How does it usually make you feel? Is there anything related to it that you'd like to explore or discuss further?
# Kid: exit
# AI Companion: Goodbye! Wishing you a speedy recovery.

# %%
import spacy
import random

class KidCompanion:
    def __init__(self):
        self.nlp = spacy.load("en_core_web_sm")

    def analyze_stress_level(self, text):
        doc = self.nlp(text)
        sentiment_score = doc.sentiment

        if sentiment_score < -0.1:
            return "high"
        elif sentiment_score < 0.1:
            return "medium"
        else:
            return "low"

    def calm_kid(self, stress_level, context):
        high_stress_responses = [
            "I understand it can be challenging, especially in the hospital. How about we focus on something positive to lighten the mood?",
            "Dealing with hospital stays is tough. Let's talk through it together. What would make you feel a bit better right now?",
            "Your strength in facing challenges is admirable. Share your thoughts, and we'll navigate through them together."
        ]

        medium_stress_responses = [
            "It's normal to feel a bit uneasy, especially in a hospital. What specific things can we discuss to make you more comfortable?",
            "Hospitals can be overwhelming, but we can find ways to make it more manageable. What activities or topics interest you?",
            "Let's create a positive distraction together. What would you enjoy chatting about right now?"
        ]

        low_stress_responses = [
            "I'm glad you're feeling okay! Hospitals aren't the most fun places. Is there anything you'd like to chat about or do to pass the time?",
            "Great to hear that you're doing well! Anything specific on your mind? We can talk about anything you like.",
            "Being in the hospital might not be ideal, but your positive attitude is inspiring. What can we do to make your day a bit brighter?"
        ]

        if stress_level == "high":
            return random.choice(high_stress_responses)
        elif stress_level == "medium":
            return random.choice(medium_stress_responses)
        else:
            return random.choice(low_stress_responses)

    def respond_to_kid_answer(self, kid_answer, stress_level):
        if "exit" in kid_answer.lower():
            return "AI Companion: It's okay. If you ever need to talk or if there's anything specific on your mind, feel free to reach out. Take care and wishing you a speedy recovery!"

        doc = self.nlp(kid_answer)
        entities = [ent.text for ent in doc.ents]

        if stress_level == "high":
            if entities:
                return f"AI Companion: I hear you. It seems like {', '.join(entities)} is important to you. How can we make your experience with {entities[0]} more positive?"
            else:
                return "AI Companion: Thank you for opening up. How about we explore some positive aspects of your day or discuss things that bring you comfort?"

        elif stress_level == "medium":
            if entities:
                return f"AI Companion: That's great to hear! {kid_answer.capitalize()} and {', '.join(entities)} both sound interesting. How do they usually make you feel? Is there anything related to them that you'd like to explore or discuss further?"
            else:
                return "AI Companion: Interesting! Let's delve a bit deeper. Is there more you'd like to share about that or any other topics you're passionate about?"

        else:
            if entities:
                return f"AI Companion: Fantastic choice! {kid_answer.capitalize()} and {', '.join(entities)} are positive topics. What other things bring you joy or make your time in the hospital more enjoyable?"
            else:
                return "AI Companion: Your positivity is contagious! Is there anything specific you'd like to chat about or do to brighten your day?"

if __name__ == "__main__":
    kid_companion = KidCompanion()

    print("AI Companion: Hi there! I'm here to chat and provide support during your time in the hospital. If you need anything specific, feel free to let me know. If you want to end our conversation, just type 'exit'.")

    while True:
        kid_input = input("Kid: ").lower()
        
        if "exit" in kid_input:
            print("AI Companion: Goodbye! Wishing you a speedy recovery.")
            break

        stress_level = kid_companion.analyze_stress_level(kid_input)
        calming_message = kid_companion.calm_kid(stress_level, kid_input)
        print("AI Companion:", calming_message)

        kid_answer = input("Kid: ")
        reply = kid_companion.respond_to_kid_answer(kid_answer, stress_level)
        print(reply)
# Out:
# AI Companion: Hi there! I'm here to chat and provide support during your time in the hospital. If you need anything specific, feel free to let me know. If you want to end our conversation, just type 'exit'.
# Kid: i am not ok in the hospitals
# AI Companion: It's normal to feel a bit uneasy, especially in a hospital. What specific things can we discuss to make you more comfortable?
# Kid: sport is my favorite topic !
# AI Companion: Interesting! Let's delve a bit deeper. Is there more you'd like to share about that or any other topics you're passionate about?
# Kid: football is my favorite sport
# AI Companion: It's normal to feel a bit uneasy, especially in a hospital. What specific things can we discuss to make you more comfortable?
# Kid: i am ok now
# AI Companion: Interesting! Let's delve a bit deeper. Is there more you'd like to share about that or any other topics you're passionate about?
# Kid: i am ok
# ...

# %%
import spacy
import random

class KidCompanion:
    def __init__(self):
        self.nlp = spacy.load("en_core_web_sm")

    def analyze_stress_level(self, text):
        doc = self.nlp(text)
        sentiment_score = doc.sentiment

        if sentiment_score < -0.1:
            return "high"
        elif sentiment_score < 0.1:
            return "medium"
        else:
            return "low"

    def calm_kid(self, stress_level, context):
        high_stress_responses = [
            "I understand it can be challenging, especially in the hospital. How about we focus on something positive to lighten the mood?",
            "Dealing with hospital stays is tough. Let's talk through it together. What would make you feel a bit better right now?",
            "Your strength in facing challenges is admirable. Share your thoughts, and we'll navigate through them together."
        ]

        medium_stress_responses = [
            "It's normal to feel a bit uneasy, especially in a hospital. What specific things can we discuss to make you more comfortable?",
            "Hospitals can be overwhelming, but we can find ways to make it more manageable. What activities or topics interest you?",
            "Let's create a positive distraction together. What would you enjoy chatting about right now?"
        ]

        low_stress_responses = [
            "I'm glad you're feeling okay! Hospitals aren't the most fun places. Is there anything you'd like to chat about or do to pass the time?",
            "Great to hear that you're doing well! Anything specific on your mind? We can talk about anything you like.",
            "Being in the hospital might not be ideal, but your positive attitude is inspiring. What can we do to make your day a bit brighter?"
        ]

        if stress_level == "high":
            return random.choice(high_stress_responses)
        elif stress_level == "medium":
            return random.choice(medium_stress_responses)
        else:
            return random.choice(low_stress_responses)

    def respond_to_kid_answer(self, kid_answer, stress_level):
        if "exit" in kid_answer.lower():
            return "AI Companion: It's okay. If you ever need to talk or if there's anything specific on your mind, feel free to reach out. Take care and wishing you a speedy recovery!"

        doc = self.nlp(kid_answer)
        entities = [ent.text for ent in doc.ents]

        if stress_level == "high":
            if entities:
                return f"AI Companion: I hear you. It seems like {', '.join(entities)} is important to you. How can we make your experience with {entities[0]} more positive?"
            else:
                return "AI Companion: Thank you for opening up. How about we explore some positive aspects of your day or discuss things that bring you comfort?"

        elif stress_level == "medium":
            if entities:
                return f"AI Companion: That's great to hear! {kid_answer.capitalize()} and {', '.join(entities)} both sound interesting. How do they usually make you feel? Is there anything related to them that you'd like to explore or discuss further?"
            else:
                return "AI Companion: Interesting! Let's delve a bit deeper. Is there more you'd like to share about that or any other topics you're passionate about?"

        else:
            if entities:
                return f"AI Companion: Fantastic choice! {kid_answer.capitalize()} and {', '.join(entities)} are positive topics. What other things bring you joy or make your time in the hospital more enjoyable?"
            else:
                return "AI Companion: Your positivity is contagious! Is there anything specific you'd like to chat about or do to brighten your day?"

def demo():
    kid_companion = KidCompanion()

    print("AI Companion: Hi there! I'm here to chat and provide support during your time in the hospital. If you need anything specific, feel free to let me know. If you want to end our conversation, just type 'exit'.")

    while True:
        kid_input = input("Kid: ").lower()
        
        if "exit" in kid_input:
            print("AI Companion: Goodbye! Wishing you a speedy recovery.")
            break

        stress_level = kid_companion.analyze_stress_level(kid_input)
        calming_message = kid_companion.calm_kid(stress_level, kid_input)
        print("AI Companion:", calming_message)

        kid_answer = input("Kid: ")
        reply = kid_companion.respond_to_kid_answer(kid_answer, stress_level)
        print(reply)

if __name__ == "__main__":
    demo()
# Out:
# AI Companion: Hi there! I'm here to chat and provide support during your time in the hospital. If you need anything specific, feel free to let me know. If you want to end our conversation, just type 'exit'.
# Kid: i am not ok
# AI Companion: Let's create a positive distraction together. What would you enjoy chatting about right now?
# Kid: my fav sport is football
# AI Companion: Interesting! Let's delve a bit deeper. Is there more you'd like to share about that or any other topics you're passionate about?
# Kid: exit
# AI Companion: Goodbye! Wishing you a speedy recovery.

# %%
import random

class KidCompanion:
    def calm_kid(self, stress_level):
        high_stress_responses = [
            "I understand it can be challenging, especially in the hospital. How about we focus on something positive to lighten the mood? What activities or topics interest you?",
            "Dealing with hospital stays is tough. Let's talk through it together. What would make you feel a bit better right now?",
            "Your strength in facing challenges is admirable. Share your thoughts, and we'll navigate through them together."
        ]

        medium_stress_responses = [
            "It's normal to feel a bit uneasy, especially in a hospital. What specific things can we discuss to make you more comfortable?",
            "Hospitals can be overwhelming, but we can find ways to make it more manageable. What activities or topics interest you?",
            "Let's create a positive distraction together. What would you enjoy chatting about right now?"
        ]

        low_stress_responses = [
            "I'm glad you're feeling okay! Hospitals aren't the most fun places. Is there anything you'd like to chat about or do to pass the time?",
            "Great to hear that you're doing well! Anything specific on your mind? We can talk about anything you like.",
            "Being in the hospital might not be ideal, but your positive attitude is inspiring. What can we do to make your day a bit brighter?"
        ]

        if stress_level == "high":
            return random.choice(high_stress_responses)
        elif stress_level == "medium":
            return random.choice(medium_stress_responses)
        else:
            return random.choice(low_stress_responses)

def demo():
    kid_companion = KidCompanion()

    print("AI Companion: Hi there! I'm here to chat and provide support during your time in the hospital. If you need anything specific, feel free to let me know. If you want to end our conversation, just type 'exit'.")

    while True:
        kid_input = input("Kid: ").lower()
        
        if "exit" in kid_input:
            print("AI Companion: Goodbye! Wishing you a speedy recovery.")
            break

        stress_level = "medium"  # Assume a medium stress level for simplicity
        calming_message = kid_companion.calm_kid(stress_level)
        print("AI Companion:", calming_message)

        kid_answer = input("Kid: ")
        print("AI Companion: That's awesome! {} sounds like a great choice. Tell me more about it or anything else you'd like to discuss.".format(kid_answer.capitalize()))

if __name__ == "__main__":
    demo()
# Out:
# AI Companion: Hi there! I'm here to chat and provide support during your time in the hospital. If you need anything specific, feel free to let me know. If you want to end our conversation, just type 'exit'.
# Kid: It's so boring in the hospital.
# AI Companion: It's normal to feel a bit uneasy, especially in a hospital. What specific things can we discuss to make you more comfortable?
# Kid: I love playing video games.
# AI Companion: That's awesome! I love playing video games. sounds like a great choice. Tell me more about it or anything else you'd like to discuss.
# Kid: I like exploring in open-world games.
# AI Companion: Hospitals can be overwhelming, but we can find ways to make it more manageable. What activities or topics interest you?
# Kid: bye
# AI Companion: That's awesome! Bye sounds like a great choice. Tell me more about it or anything else you'd like to discuss.
# Kid: exit
# AI Companion: Goodbye! Wishing you a speedy recovery.

# %%
import random

class KidCompanion:
    def __init__(self):
        self.stress_level = "medium"  # Default stress level

    def analyze_stress_level(self, text):
        # Placeholder function for stress level analysis (you might use an NLP library for this)
        return "medium"

    def calm_kid(self):
        high_stress_responses = [
            "I understand it can be challenging, especially in the hospital. How about we focus on something positive to lighten the mood? What activities or topics interest you?",
            "Dealing with hospital stays is tough. Let's talk through it together. What would make you feel a bit better right now?",
            "Your strength in facing challenges is admirable. Share your thoughts, and we'll navigate through them together."
        ]

        medium_stress_responses = [
            "It's normal to feel a bit uneasy, especially in a hospital. What specific things can we discuss to make you more comfortable?",
            "Hospitals can be overwhelming, but we can find ways to make it more manageable. What activities or topics interest you?",
            "Let's create a positive distraction together. What would you enjoy chatting about right now?"
        ]

        low_stress_responses = [
            "I'm glad you're feeling okay! Hospitals aren't the most fun places. Is there anything you'd like to chat about or do to pass the time?",
            "Great to hear that you're doing well! Anything specific on your mind? We can talk about anything you like.",
            "Being in the hospital might not be ideal, but your positive attitude is inspiring. What can we do to make your day a bit brighter?"
        ]

        if self.stress_level == "high":
            return random.choice(high_stress_responses)
        elif self.stress_level == "medium":
            return random.choice(medium_stress_responses)
        else:
            return random.choice(low_stress_responses)

    def respond_to_kid_input(self, kid_input):
        self.stress_level = self.analyze_stress_level(kid_input)

        if "exit" in kid_input.lower():
            return "AI Companion: It's okay. If you ever need to talk or if there's anything specific on your mind, feel free to reach out. Take care and wishing you a speedy recovery!"

        if "open-world games" in kid_input.lower():
            return "AI Companion: That's awesome! Exploring virtual worlds is fascinating. What do you enjoy most about the adventures in open-world games? Is there a specific game you're currently into?"

        if "build" in kid_input.lower():
            return "AI Companion: Building and creating things is so cool! What inspired you to start building in games? Is there a particular creation you're proud of?"

        if "friends" in kid_input.lower():
            return "AI Companion: Missing your friends is completely understandable. Let's think about ways to stay connected. What activities do you usually enjoy doing together?"

        return "AI Companion: " + self.calm_kid()

def chatbot_demo():
    kid_companion = KidCompanion()

    print("AI Companion: Hi there! I'm here to chat and provide support during your time in the hospital. If you need anything specific, feel free to let me know. If you want to end our conversation, just type 'exit'.")

    while True:
        kid_input = input("Kid: ")
        response = kid_companion.respond_to_kid_input(kid_input)
        print(response)

        if "exit" in kid_input.lower():
            print("AI Companion: Goodbye! Wishing you a speedy recovery.")
            break

if __name__ == "__main__":
    chatbot_demo()
# Out:
# AI Companion: Hi there! I'm here to chat and provide support during your time in the hospital. If you need anything specific, feel free to let me know. If you want to end our conversation, just type 'exit'.
# Kid: i am not ok
# AI Companion: It's normal to feel a bit uneasy, especially in a hospital. What specific things can we discuss to make you more comfortable?
# Kid: i would like to talk about my friends
# AI Companion: Missing your friends is completely understandable. Let's think about ways to stay connected. What activities do you usually enjoy doing together?
# Kid: playing sports
# AI Companion: It's normal to feel a bit uneasy, especially in a hospital. What specific things can we discuss to make you more comfortable?
# Kid: and also playing video games
# AI Companion: Let's create a positive distraction together. What would you enjoy chatting about right now?
# Kid: video games
# ...

# %%
import random

class KidCompanion:
    def __init__(self):
        self.stress_level = "medium"  # Default stress level

    def analyze_stress_level(self, text):
        # Placeholder function for stress level analysis (you might use an NLP library for this)
        return "medium"

    def calm_kid(self):
        high_stress_responses = [
            "I understand it can be challenging, especially in the hospital. How about we focus on something positive to lighten the mood? What activities or topics interest you?",
            "Dealing with hospital stays is tough. Let's talk through it together. What would make you feel a bit better right now?",
            "Your strength in facing challenges is admirable. Share your thoughts, and we'll navigate through them together."
        ]

        medium_stress_responses = [
            "It's normal to feel a bit uneasy, especially in a hospital. What specific things can we discuss to make you more comfortable?",
            "Hospitals can be overwhelming, but we can find ways to make it more manageable. What activities or topics interest you?",
            "Let's create a positive distraction together. What would you enjoy chatting about right now?"
        ]

        low_stress_responses = [
            "I'm glad you're feeling okay! Hospitals aren't the most fun places. Is there anything you'd like to chat about or do to pass the time?",
            "Great to hear that you're doing well! Anything specific on your mind? We can talk about anything you like.",
            "Being in the hospital might not be ideal, but your positive attitude is inspiring. What can we do to make your day a bit brighter?"
        ]

        if self.stress_level == "high":
            return random.choice(high_stress_responses)
        elif self.stress_level == "medium":
            return random.choice(medium_stress_responses)
        else:
            return random.choice(low_stress_responses)

    def respond_to_kid_input(self, kid_input):
        self.stress_level = self.analyze_stress_level(kid_input)

        if "exit" in kid_input.lower():
            return "AI Companion: It's okay. If you ever need to talk or if there's anything specific on your mind, feel free to reach out. Take care and wishing you a speedy recovery!"

        if "video games" in kid_input.lower():
            return "AI Companion: That's fantastic! Video games can be a great way to escape and have fun. What's your favorite game, and why do you enjoy playing it?"

        if "sports" in kid_input.lower():
            return "AI Companion: Sports are awesome! Whether you're a player or a fan, they bring people together. Do you have a favorite sport or team?"

        if "build" in kid_input.lower():
            return "AI Companion: Building and creating things is so cool! What inspired you to start building in games? Is there a particular creation you're proud of?"

        if "friends" in kid_input.lower():
            return "AI Companion: Missing your friends is completely understandable. Let's think about ways to stay connected. What activities do you usually enjoy doing together?"

        if "ok" in kid_input.lower() or "okay" in kid_input.lower() or "fine" in kid_input.lower():
            return "AI Companion: That's great to hear! If there's anything specific you'd like to chat about or if you have any questions, feel free to let me know."

        return "AI Companion: " + self.calm_kid()

def chatbot_demo():
    kid_companion = KidCompanion()

    print("AI Companion: Hi there! I'm here to chat and provide support during your time in the hospital. If you need anything specific, feel free to let me know. If you want to end our conversation, just type 'exit'.")

    while True:
        kid_input = input("Kid: ")
        response = kid_companion.respond_to_kid_input(kid_input)
        print(response)

        if "exit" in kid_input.lower():
            print("AI Companion: Goodbye! Wishing you a speedy recovery.")
            break

if __name__ == "__main__":
    chatbot_demo()
# Out:
# AI Companion: Hi there! I'm here to chat and provide support during your time in the hospital. If you need anything specific, feel free to let me know. If you want to end our conversation, just type 'exit'.
# Kid: i am upset and bored in the hospital
# AI Companion: It's normal to feel a bit uneasy, especially in a hospital. What specific things can we discuss to make you more comfortable?
# Kid: i would like to talk about my friends
# AI Companion: Missing your friends is completely understandable. Let's think about ways to stay connected. What activities do you usually enjoy doing together?
# Kid: playing video games
# AI Companion: That's fantastic! Video games can be a great way to escape and have fun. What's your favorite game, and why do you enjoy playing it?
# Kid: sport
# AI Companion: Let's create a positive distraction together. What would you enjoy chatting about right now?
# Kid: thanks i am ok now
# ...

# %%
import random

class KidCompanion:
    def __init__(self):
        self.stress_level = "medium"  # Default stress level

    def analyze_stress_level(self, text):
        # Placeholder function for stress level analysis (you might use an NLP library for this)
        return "medium"

    def calm_kid(self):
        high_stress_responses = [
            "I understand it can be challenging, especially in the hospital. How about we focus on something positive to lighten the mood? What activities or topics interest you?",
            "Dealing with hospital stays is tough. Let's talk through it together. What would make you feel a bit better right now?",
            "Your strength in facing challenges is admirable. Share your thoughts, and we'll navigate through them together."
        ]

        medium_stress_responses = [
            "It's normal to feel a bit uneasy, especially in a hospital. What specific things can we discuss to make you more comfortable?",
            "Hospitals can be overwhelming, but we can find ways to make it more manageable. What activities or topics interest you?",
            "Let's create a positive distraction together. What would you enjoy chatting about right now?"
        ]

        low_stress_responses = [
            "I'm glad you're feeling okay! Hospitals aren't the most fun places. Is there anything you'd like to chat about or do to pass the time?",
            "Great to hear that you're doing well! Anything specific on your mind? We can talk about anything you like.",
            "Being in the hospital might not be ideal, but your positive attitude is inspiring. What can we do to make your day a bit brighter?"
        ]

        if self.stress_level == "high":
            return random.choice(high_stress_responses)
        elif self.stress_level == "medium":
            return random.choice(medium_stress_responses)
        else:
            return random.choice(low_stress_responses)

    def respond_to_kid_input(self, kid_input):
        self.stress_level = self.analyze_stress_level(kid_input)

        if "exit" in kid_input.lower():
            return "AI Companion: Goodbye! Wishing you a speedy recovery. Sending you lots of positive vibes for a brighter day!"

        if "video games" in kid_input.lower():
            return "AI Companion: That's fantastic! Video games can be a great way to escape and have fun. What's your favorite game, and why do you enjoy playing it?"

        if "sports" in kid_input.lower():
            return "AI Companion: Sports are awesome! Whether you're a player or a fan, they bring people together. Do you have a favorite sport or team?"

        if "build" in kid_input.lower():
            return "AI Companion: Building and creating things is so cool! What inspired you to start building in games? Is there a particular creation you're proud of?"

        if "friends" in kid_input.lower():
            return "AI Companion: Missing your friends is completely understandable. Let's think about ways to stay connected. What activities do you usually enjoy doing together?"

        if "ok" in kid_input.lower() or "okay" in kid_input.lower() or "fine" in kid_input.lower():
            return "AI Companion: That's great to hear! If there's anything specific you'd like to chat about or if you have any questions, feel free to let me know."

        return "AI Companion: " + self.calm_kid()

def chatbot_demo():
    kid_companion = KidCompanion()

    print("AI Companion: Hi there! I'm here to chat and provide support during your time in the hospital. If you need anything specific, feel free to let me know. If you want to end our conversation, just type 'exit'.")

    while True:
        kid_input = input("Kid: ")
        response = kid_companion.respond_to_kid_input(kid_input)
        print(response)

        if "exit" in kid_input.lower():
            print("AI Companion: Goodbye! Wishing you a speedy recovery. Sending you lots of positive vibes for a brighter day!")
            break

if __name__ == "__main__":
    chatbot_demo()
# Out:
# AI Companion: Hi there! I'm here to chat and provide support during your time in the hospital. If you need anything specific, feel free to let me know. If you want to end our conversation, just type 'exit'.
# Kid: i am bored and upset at hospital
# AI Companion: Let's create a positive distraction together. What would you enjoy chatting about right now?
# Kid: i would like to talk about my friends
# AI Companion: Missing your friends is completely understandable. Let's think about ways to stay connected. What activities do you usually enjoy doing together?
# Kid: we are playing video games together!
# AI Companion: That's fantastic! Video games can be a great way to escape and have fun. What's your favorite game, and why do you enjoy playing it?
# Kid: mostly sport games!
# AI Companion: Let's create a positive distraction together. What would you enjoy chatting about right now?
# Kid: thanks I am good and feel better now!
# ...

# %%
import random

class KidCompanion:
    def __init__(self):
        self.stress_level = "medium"  # Default stress level

    def analyze_stress_level(self, text):
        # Placeholder function for stress level analysis (you might use an NLP library for this)
        return "medium"

    def is_feeling_fine(self, text):
        # Check if the kid's input contains words like "good" or "ok"
        return any(word in text.lower() for word in ["good", "ok"])

    def contains_bye(self, text):
        # Check if the kid's input contains the word "bye"
        return "bye" in text.lower()

    def calm_kid(self):
        high_stress_responses = [
            "I understand it can be challenging, especially in the hospital. How about we focus on something positive to lighten the mood? What activities or topics interest you?",
            "Dealing with hospital stays is tough. Let's talk through it together. What would make you feel a bit better right now?",
            "Your strength in facing challenges is admirable. Share your thoughts, and we'll navigate through them together."
        ]

        medium_stress_responses = [
            "It's normal to feel a bit uneasy, especially in a hospital. What specific things can we discuss to make you more comfortable?",
            "Hospitals can be overwhelming, but we can find ways to make it more manageable. What activities or topics interest you?",
            "Let's create a positive distraction together. What would you enjoy chatting about right now?"
        ]

        low_stress_responses = [
            "I'm glad you're feeling okay! Hospitals aren't the most fun places. Is there anything you'd like to chat about or do to pass the time?",
            "Great to hear that you're doing well! Anything specific on your mind? We can talk about anything you like.",
            "Being in the hospital might not be ideal, but your positive attitude is inspiring. What can we do to make your day a bit brighter?"
        ]

        if self.stress_level == "high":
            return random.choice(high_stress_responses)
        elif self.stress_level == "medium":
            return random.choice(medium_stress_responses)
        else:
            return random.choice(low_stress_responses)

    def respond_to_kid_input(self, kid_input):
        self.stress_level = self.analyze_stress_level(kid_input)

        if self.contains_bye(kid_input):
            return "AI Companion: Goodbye! Wishing you a speedy recovery. Sending you lots of positive vibes for a brighter day!"

        if "exit" in kid_input.lower():
            return "AI Companion: Goodbye! Wishing you a speedy recovery. Sending you lots of positive vibes for a brighter day!"

        if self.is_feeling_fine(kid_input):
            return "AI Companion: That's wonderful to hear! If there's anything specific you'd like to chat about or if you have any questions, feel free to let me know."

        if "video games" in kid_input.lower():
            return "AI Companion: That's fantastic! Video games can be a great way to escape and have fun. What's your favorite game, and why do you enjoy playing it?"

        if "sports" in kid_input.lower():
            return "AI Companion: Sports are awesome! Whether you're a player or a fan, they bring people together. Do you have a favorite sport or team?"

        if "build" in kid_input.lower():
            return "AI Companion: Building and creating things is so cool! What inspired you to start building in games? Is there a particular creation you're proud of?"

        if "friends" in kid_input.lower():
            return "AI Companion: Missing your friends is completely understandable. Let's think about ways to stay connected. What activities do you usually enjoy doing together?"

        return "AI Companion: " + self.calm_kid()

def chatbot_demo():
    kid_companion = KidCompanion()

    print("AI Companion: Hi there! I'm here to chat and provide support during your time in the hospital. If you need anything specific, feel free to let me know. If you want to end our conversation, just type 'exit'.")

    while True:
        kid_input = input("Kid: ")
        response = kid_companion.respond_to_kid_input(kid_input)
        print(response)

        if kid_companion.contains_bye(kid_input):
            print("AI Companion: Goodbye! Wishing you a speedy recovery. Sending you lots of positive vibes for a brighter day!")
            break

        if "exit" in kid_input.lower():
            print("AI Companion: Goodbye! Wishing you a speedy recovery. Sending you lots of positive vibes for a brighter day!")
            break

if __name__ == "__main__":
    chatbot_demo()
# Out:
# AI Companion: Hi there! I'm here to chat and provide support during your time in the hospital. If you need anything specific, feel free to let me know. If you want to end our conversation, just type 'exit'.
# Kid: i am bored and upset at hospital!
# AI Companion: It's normal to feel a bit uneasy, especially in a hospital. What specific things can we discuss to make you more comfortable?
# Kid: we are playing video games!
# AI Companion: That's fantastic! Video games can be a great way to escape and have fun. What's your favorite game, and why do you enjoy playing it?
# Kid: we are playing sport games together!
# AI Companion: Hospitals can be overwhelming, but we can find ways to make it more manageable. What activities or topics interest you?
# Kid: sport
# AI Companion: Hospitals can be overwhelming, but we can find ways to make it more manageable. What activities or topics interest you?
# Kid: i am feeling better and good and ok now!
# ...

# %%
import random
from textblob import TextBlob

class KidCompanion:
    def __init__(self):
        self.stress_level = "medium"  # Default stress level

    def analyze_stress_level(self, text):
        # Placeholder function for stress level analysis (you might use an NLP library for this)
        return "medium"

    def calculate_sentiment_score(self, text):
        analysis = TextBlob(text)
        # The sentiment polarity ranges from -1 to 1 (negative to positive)
        return analysis.sentiment.polarity

    def is_feeling_fine(self, text):
        # Check if the kid's input contains words like "good" or "ok"
        return any(word in text.lower() for word in ["good", "ok"])

    def contains_bye(self, text):
        # Check if the kid's input contains the word "bye"
        return "bye" in text.lower()

    def calm_kid(self):
        high_stress_responses = [
            "I understand it can be challenging, especially in the hospital. How about we focus on something positive to lighten the mood? What activities or topics interest you?",
            "Dealing with hospital stays is tough. Let's talk through it together. What would make you feel a bit better right now?",
            "Your strength in facing challenges is admirable. Share your thoughts, and we'll navigate through them together."
        ]

        medium_stress_responses = [
            "It's normal to feel a bit uneasy, especially in a hospital. What specific things can we discuss to make you more comfortable?",
            "Hospitals can be overwhelming, but we can find ways to make it more manageable. What activities or topics interest you?",
            "Let's create a positive distraction together. What would you enjoy chatting about right now?"
        ]

        low_stress_responses = [
            "I'm glad you're feeling okay! Hospitals aren't the most fun places. Is there anything you'd like to chat about or do to pass the time?",
            "Great to hear that you're doing well! Anything specific on your mind? We can talk about anything you like.",
            "Being in the hospital might not be ideal, but your positive attitude is inspiring. What can we do to make your day a bit brighter?"
        ]

        if self.stress_level == "high":
            return random.choice(high_stress_responses)
        elif self.stress_level == "medium":
            return random.choice(medium_stress_responses)
        else:
            return random.choice(low_stress_responses)

    def respond_to_kid_input(self, kid_input):
        self.stress_level = self.analyze_stress_level(kid_input)

        if self.contains_bye(kid_input):
            return "AI Companion: Goodbye! Wishing you a speedy recovery. Sending you lots of positive vibes for a brighter day!"

        if "exit" in kid_input.lower():
            return "AI Companion: Goodbye! Wishing you a speedy recovery. Sending you lots of positive vibes for a brighter day!"

        # Calculate sentiment score for the first output
        sentiment_score = self.calculate_sentiment_score(kid_input)

        if sentiment_score > 0:
            sentiment_response = "AI Companion: It sounds like you're feeling positive. That's wonderful! "
        elif sentiment_score < 0:
            sentiment_response = "AI Companion: I'm here for you. If you're feeling down, we can work through it together. "
        else:
            sentiment_response = "AI Companion: Your message is neutral. How can I assist you today? "

        if self.is_feeling_fine(kid_input):
            return sentiment_response + "If there's anything specific you'd like to chat about or if you have any questions, feel free to let me know."

        if "video games" in kid_input.lower():
            return sentiment_response + "Video games can be a great way to escape and have fun. What's your favorite game, and why do you enjoy playing it?"

        if "sports" in kid_input.lower():
            return sentiment_response + "Sports are awesome! Whether you're a player or a fan, they bring people together. Do you have a favorite sport or team?"

        if "build" in kid_input.lower():
            return sentiment_response + "Building and creating things is so cool! What inspired you to start building in games? Is there a particular creation you're proud of?"

        if "friends" in kid_input.lower():
            return sentiment_response + "Missing your friends is completely understandable. Let's think about ways to stay connected. What activities do you usually enjoy doing together?"

        return sentiment_response + self.calm_kid()

def chatbot_demo():
    kid_companion = KidCompanion()

    print("AI Companion: Hi there! I'm here to chat and provide support during your time in the hospital. If you need anything specific, feel free to let me know. If you want to end our conversation, just type 'exit'.")

    while True:
        kid_input = input("Kid: ")
        response = kid_companion.respond_to_kid_input(kid_input)
        print(response)

        if kid_companion.contains_bye(kid_input):
            print("AI Companion: Goodbye! Wishing you a speedy recovery. Sending you lots of positive vibes for a brighter day!")
            break

        if "exit" in kid_input.lower():
            print("AI Companion: Goodbye! Wishing you a speedy recovery. Sending you lots of positive vibes for a brighter day!")
            break

if __name__ == "__main__":
    chatbot_demo()
# Out:
# AI Companion: Hi there! I'm here to chat and provide support during your time in the hospital. If you need anything specific, feel free to let me know. If you want to end our conversation, just type 'exit'.
# Kid: i am bored in hospital
# AI Companion: I'm here for you. If you're feeling down, we can work through it together. It's normal to feel a bit uneasy, especially in a hospital. What specific things can we discuss to make you more comfortable?
# Kid: i like to be with my friends
# AI Companion: Your message is neutral. How can I assist you today? Missing your friends is completely understandable. Let's think about ways to stay connected. What activities do you usually enjoy doing together?
# Kid: we are playing video games
# AI Companion: Your message is neutral. How can I assist you today? Video games can be a great way to escape and have fun. What's your favorite game, and why do you enjoy playing it?
# Kid: sport game
# ...

# %%
# Create an instance of KidCompanion
kid_companion = KidCompanion()

# Get the sentiment score for a given input text
input_text = "I love playing video games!"
sentiment_score = kid_companion.calculate_sentiment_score(input_text)

# Print the sentiment score
print(f"Sentiment Score: {sentiment_score}")
# Out:
# Sentiment Score: 0.625
